# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv('1.csv', delimiter=',', sep='\t')
a
# Out:
#      Unnamed: 0  mpg:  cylinders:  displacement:  horsepower:  weight:  \
# 0             0  18.0           8          307.0          130     3504
# 1             1  15.0           8          350.0          165     3693
# 2             2  18.0           8          318.0          150     3436
# 3             3  16.0           8          304.0          150     3433
# 4             4  17.0           8          302.0          140     3449
# ..          ...   ...         ...            ...          ...      ...
# 387         393  27.0           4          140.0           86     2790
# 388         394  44.0           4           97.0           52     2130
# 389         395  32.0           4          135.0           84     2295
# 390         396  28.0           4          120.0           79     2625
# 391         397  31.0           4          119.0           82     2720
#
#      acceleration:  model_year:  origin:                      car_name:
# ...

# %% [markdown]
# ## droping 1 column which is un necessary

# %%
a.drop(a.columns[0],axis=1, inplace=True)
a
# Out:
#      mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 0    18.0           8          307.0          130     3504           12.0
# 1    15.0           8          350.0          165     3693           11.5
# 2    18.0           8          318.0          150     3436           11.0
# 3    16.0           8          304.0          150     3433           12.0
# 4    17.0           8          302.0          140     3449           10.5
# ..    ...         ...            ...          ...      ...            ...
# 387  27.0           4          140.0           86     2790           15.6
# 388  44.0           4           97.0           52     2130           24.6
# 389  32.0           4          135.0           84     2295           11.6
# 390  28.0           4          120.0           79     2625           18.6
# 391  31.0           4          119.0           82     2720           19.4
#
#      model_year:  origin:                      car_name:
# ...

# %%
a.head()
# Out:
#    mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 0  18.0           8          307.0          130     3504           12.0
# 1  15.0           8          350.0          165     3693           11.5
# 2  18.0           8          318.0          150     3436           11.0
# 3  16.0           8          304.0          150     3433           12.0
# 4  17.0           8          302.0          140     3449           10.5
#
#    model_year:  origin:                      car_name:
# 0           70        1  \t"chevrolet chevelle malibu"
# 1           70        1          \t"buick skylark 320"
# 2           70        1         \t"plymouth satellite"
# 3           70        1              \t"amc rebel sst"
# 4           70        1                \t"ford torino"

# %% [markdown]
# ## Cleaning car names of space and characters

# %%
a=a.replace('"','',regex=True).replace('\t',"",regex=True)
# replace('\"',"")
a
# Out:
#      mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 0    18.0           8          307.0          130     3504           12.0
# 1    15.0           8          350.0          165     3693           11.5
# 2    18.0           8          318.0          150     3436           11.0
# 3    16.0           8          304.0          150     3433           12.0
# 4    17.0           8          302.0          140     3449           10.5
# ..    ...         ...            ...          ...      ...            ...
# 387  27.0           4          140.0           86     2790           15.6
# 388  44.0           4           97.0           52     2130           24.6
# 389  32.0           4          135.0           84     2295           11.6
# 390  28.0           4          120.0           79     2625           18.6
# 391  31.0           4          119.0           82     2720           19.4
#
#      model_year:  origin:                  car_name:
# ...

# %% [markdown]
# ## Checking null values

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg:           392 non-null    float64
#  1   cylinders:     392 non-null    int64
#  2   displacement:  392 non-null    float64
#  3   horsepower:    392 non-null    int64
#  4   weight:        392 non-null    int64
#  5   acceleration:  392 non-null    float64
#  6   model_year:    392 non-null    int64
#  7   origin:        392 non-null    int64
#  8   car_name:      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %% [markdown]
# ## Droping null rows

# %%
a.dropna(axis=1,inplace=True)
a
# Out:
#      mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 0    18.0           8          307.0          130     3504           12.0
# 1    15.0           8          350.0          165     3693           11.5
# 2    18.0           8          318.0          150     3436           11.0
# 3    16.0           8          304.0          150     3433           12.0
# 4    17.0           8          302.0          140     3449           10.5
# ..    ...         ...            ...          ...      ...            ...
# 387  27.0           4          140.0           86     2790           15.6
# 388  44.0           4           97.0           52     2130           24.6
# 389  32.0           4          135.0           84     2295           11.6
# 390  28.0           4          120.0           79     2625           18.6
# 391  31.0           4          119.0           82     2720           19.4
#
#      model_year:  origin:                  car_name:
# ...

# %%
a.isnull().sum()
# Out:
# mpg:             0
# cylinders:       0
# displacement:    0
# horsepower:      0
# weight:          0
# acceleration:    0
# model_year:      0
# origin:          0
# car_name:        0
# dtype: int64

# %% [markdown]
# ## Null values as '?'

# %%
print(a[a['horsepower:']== '?'])
# Out:
# Empty DataFrame
# Columns: [mpg:, cylinders:, displacement:, horsepower:, weight:, acceleration:, model_year:, origin:, car_name:]
# Index: []

# %% [markdown]
# ## Null value '?' handled

# %%
b=a[a['horsepower:']!= '?']
b
# Out:
#      mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 0    18.0           8          307.0          130     3504           12.0
# 1    15.0           8          350.0          165     3693           11.5
# 2    18.0           8          318.0          150     3436           11.0
# 3    16.0           8          304.0          150     3433           12.0
# 4    17.0           8          302.0          140     3449           10.5
# ..    ...         ...            ...          ...      ...            ...
# 387  27.0           4          140.0           86     2790           15.6
# 388  44.0           4           97.0           52     2130           24.6
# 389  32.0           4          135.0           84     2295           11.6
# 390  28.0           4          120.0           79     2625           18.6
# 391  31.0           4          119.0           82     2720           19.4
#
#      model_year:  origin:                  car_name:
# ...

# %%
a['car_name:'].value_counts()
# Out:
# amc matador                   5
# ford pinto                    5
# toyota corolla                5
# peugeot 504                   4
# amc gremlin                   4
#                              ..
# pontiac j2000 se hatchback    1
# ford granada gl               1
# mazda rx-7 gs                 1
# dodge charger 2.2             1
# chevrolet vega (sw)           1
# Name: car_name:, Length: 301, dtype: int64

# %% [markdown]
# ## Grouping cars together and its attributes

# %%
c=a.groupby('car_name:')
print(c.get_group('ford country squire (sw)'))
amc_matador=c.get_group('amc matador')
ford_pinto=c.get_group('ford pinto')
toyota_corolla =c.get_group('toyota corolla')
chevrolet_impala=c.get_group('chevrolet impala')
amc_matador.describe()
li=['mpg:','horsepower:','cylinders:','acceleration:']
a1=[]
a2=[]
a3=[]
a4=[]
for i in li:
    max_value= amc_matador[i].max()
    a1.append(max_value)
for i in li:
    max_value= ford_pinto[i].max()
    a2.append(max_value)
for i in li:
    max_value= toyota_corolla[i].max()
    a3.append(max_value)
for i in li:
    max_value= chevrolet_impala[i].max()
    a4.append(max_value)
# Out:
#      mpg:  cylinders:  displacement:  horsepower:  weight:  acceleration:  \
# 42   13.0           8          400.0          170     4746           12.0
# 288  15.5           8          351.0          142     4054           14.3
#
#      model_year:  origin:                 car_name:
# 42            71        1  ford country squire (sw)
# 288           79        1  ford country squire (sw)

# %% [markdown]
# ## Segmenting cars

# %%
name=['amc_matador','ford_pinto','toyota_corolla','chevrolet_impala']
a1
mpg=[]
hp=[]
cyc=[]
acc=[]
def u(a,b,c,d,e):
    for i in range(1):
        a.append(b[i])
        c.append(b[i])
        d.append(b[i])
        e.append(b[i])

u(mpg,a1,hp,cyc,acc)
u(mpg,a2,hp,cyc,acc)
u(mpg,a3,hp,cyc,acc)
u(mpg,a4,hp,cyc,acc)
mpg
# Out:
# [18.0, 26.5, 34.0, 14.0]

# %% [markdown]
# ## Performing analysis on Cars to find out best car

# %%
import numpy as np
X = np.arange(4)
plt.figure(figsize=(15,8))
plt.bar(X+.00, a1, color = 'b', width = 0.20,label='MPG')
plt.bar(X + 0.20, a2, color = 'g', width = 0.20, label='Horse_power')
plt.bar(X + 0.40, a3, color = 'r', width = 0.20, label='Cylinder')
plt.bar(X + .60, a4, color = 'orange', width = 0.20, label='Acceleration')
plt.xticks(X, name)
plt.legend()
plt.show()
# plt.bar(, data[1], color = 'g', width = 0.25)

# %% [markdown]
# ## By looking at the graph,  Ford Pinto is the best car in terms of MPG, HP, Cylinder & Acceleration. Amc_Matador came in second.

# %%
# b=a['car_name:'].split('\t')
# print(b)
# a['car_name:'=='chevrolet chevelle malibu']

# %%
# a.isnull().values().any()

# %%
b.info()
# b.to_csv("1.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg:           392 non-null    float64
#  1   cylinders:     392 non-null    int64
#  2   displacement:  392 non-null    float64
#  3   horsepower:    392 non-null    int64
#  4   weight:        392 non-null    int64
#  5   acceleration:  392 non-null    float64
#  6   model_year:    392 non-null    int64
#  7   origin:        392 non-null    int64
#  8   car_name:      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
b['horsepower:'].astype('int32')
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 387     86
# 388     52
# 389     84
# 390     79
# 391     82
# Name: horsepower:, Length: 392, dtype: int32

# %%
import matplotlib.pyplot as plt
plt.boxplot(b['mpg:'])
plt.show()

# %% [markdown]
# ## Since our data has outlliers so the distribtion would be best displayed by mean

# %%
import matplotlib.pyplot as plt
plt.boxplot(b['horsepower:'])
plt.show()

# %% [markdown]
# ## Since our data has outlliers so the distribtion would be best displayed by median or mode

# %%
b['mpg:'].plot.kde(xlim=(b['mpg:'].min(),b['mpg:'].max()),title='Distribution for MPG')
plt.axvline(b['mpg:'].mean() ,color="black", label="mean")
plt.axvline(b['mpg:'].mode()[0],color="red", label="mode")
plt.axvline(b['mpg:'].median(),color="green",label="median")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))
b['horsepower:'].plot.kde(xlim=(b['horsepower:'].min(),b['horsepower:'].max()),title='Distribution for Horsepower')
plt.axvline(b['horsepower:'].mean() ,color="black", label="mean")
plt.axvline(b['horsepower:'].mode()[0],color="red", label="mode")
plt.axvline(b['horsepower:'].median(),color="green",label="median")
plt.legend()
plt.show()

# %%
b.describe()
# Out:
#              mpg:  cylinders:  displacement:  horsepower:      weight:  \
# count  392.000000  392.000000     392.000000   392.000000   392.000000
# mean    23.445918    5.471939     194.411990   104.469388  2977.584184
# std      7.805007    1.705783     104.644004    38.491160   849.402560
# min      9.000000    3.000000      68.000000    46.000000  1613.000000
# 25%     17.000000    4.000000     105.000000    75.000000  2225.250000
# 50%     22.750000    4.000000     151.000000    93.500000  2803.500000
# 75%     29.000000    8.000000     275.750000   126.000000  3614.750000
# max     46.600000    8.000000     455.000000   230.000000  5140.000000
#
#        acceleration:  model_year:     origin:
# count     392.000000   392.000000  392.000000
# mean       15.541327    75.979592    1.576531
# std         2.758864     3.683737    0.805518
# min         8.000000    70.000000    1.000000
# 25%        13.775000    73.000000    1.000000
# 50%        15.500000    76.000000    1.000000
# ...
